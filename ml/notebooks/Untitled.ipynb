# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/raw/startup_ideas.csv")

df.head()
# Out:
#    idea_id      startup_name  \
# 0        1       LaundryLoop
# 1        2     StudyBuddy AI
# 2        3       InvoiceFlow
# 3        4  QuickCart Campus
# 4        5       ResumeFixer
#
#                                     idea_description  \
# 0  A marketplace that connects college students w...
# 1  An AI tutor that explains difficult academic c...
# 2  A simple invoice generator and payment reminde...
# 3  A hyperlocal grocery delivery service operatin...
# 4  A tool that analyzes resumes against job descr...
#
#                        target_customer  \
# 0   College students living in hostels
# 1                     College students
# 2     Freelancers and small businesses
# 3  College students living on campuses
# 4             Students and job seekers
#
#                                    problem_statement  \
# 0  College students struggle to find reliable, af...
# 1  Students struggle to understand difficult topi...
# 2  Small businesses struggle to create profession...
# ...

# %%
print("Dataset shape:", df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)
# Out:
# Dataset shape: (10, 23)
#
# Column names:
# ['idea_id', 'startup_name', 'idea_description', 'target_customer', 'problem_statement', 'proposed_solution', 'industry', 'business_model', 'problem_clarity', 'customer_urgency', 'technical_complexity', 'monetization_clarity', 'acquisition_difficulty', 'competition_level', 'validation_evidence', 'mvp_complexity', 'overall_uncertainty', 'validation_readiness', 'startup_archetype', 'annotation_explanation', 'annotator_id', 'rubric_version', 'data_source']
#
# Data types:
# idea_id                   int64
# startup_name                str
# idea_description            str
# target_customer             str
# problem_statement           str
# proposed_solution           str
# industry                    str
# business_model              str
# problem_clarity           int64
# customer_urgency          int64
# technical_complexity      int64
# monetization_clarity      int64
# acquisition_difficulty    int64
# competition_level         int64
# ...

# %%
df.describe()
# Out:
#         idea_id  problem_clarity  customer_urgency  technical_complexity  \
# count  10.00000        10.000000         10.000000             10.000000
# mean    5.50000         8.100000          6.700000              5.300000
# std     3.02765         0.567646          0.674949              1.766981
# min     1.00000         7.000000          6.000000              3.000000
# 25%     3.25000         8.000000          6.000000              4.000000
# 50%     5.50000         8.000000          7.000000              5.500000
# 75%     7.75000         8.000000          7.000000              6.750000
# max    10.00000         9.000000          8.000000              8.000000
#
#        monetization_clarity  acquisition_difficulty  competition_level  \
# count             10.000000                10.00000          10.000000
# mean               6.100000                 5.80000           6.700000
# std                1.100505                 1.75119           1.159502
# ...

# %%
score_columns = [
    "problem_clarity",
    "customer_urgency",
    "technical_complexity",
    "monetization_clarity",
    "acquisition_difficulty",
    "competition_level",
    "validation_evidence",
    "mvp_complexity",
    "overall_uncertainty",
]

df[score_columns].hist(
    figsize=(16, 12),
    bins=5,
    edgecolor="black"
)

plt.suptitle("Distribution of DeluluScore Evaluation Features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    df[score_columns].corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Between Evaluation Features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    data=df,
    x="startup_name",
    y="overall_uncertainty"
)

plt.xticks(rotation=30, ha="right")
plt.title("Overall Uncertainty by Startup Idea")
plt.ylabel("Overall Uncertainty")
plt.xlabel("Startup")
plt.tight_layout()
plt.show()

# %%
print("Dataset shape:", df.shape)
